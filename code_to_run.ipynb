# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
% cd gdrive/MyDrive/PrGAN-master/
# Out:
# /content/gdrive/MyDrive/PrGAN-master

# %%
# !python2 src/PrGAN.py -d airplane64 --train -e 1
# Out:
# 2021-05-13 17:37:41.894582: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-05-13 17:37:41.928393: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-13 17:37:41.929036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-05-13 17:37:41.931929: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-13 17:37:41.943806: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...

# %%
! python2 src/create_cubes.py "results/PrGANairplane64/*.npy" 0.5
# Out:
# Creating Sunflow Cubes from  results/PrGANairplane64/*.npy
# Using threshold  0.5
# Done.
